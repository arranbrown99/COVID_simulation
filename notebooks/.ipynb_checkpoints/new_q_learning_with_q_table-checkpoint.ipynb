# %%
# use full window width
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import os
import numpy as np
os.chdir('..')
import virl
from plot_helper import plot
from q_learning_tabular.q_table import QTable
from q_learning_tabular.q_learning_agent import QLearningAgent
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Training and dumping q_tables for all problem ids

# %%
for i in range(0,10):
    filename = "q_learning_tabular_problem_id_" + str(i) + ".txt"    
    env = virl.Epidemic(stochastic=False, noisy=False)
    agent = QLearningAgent(env, print_out_every_x_episodes=250)
    agent.train()
    q_table = agent.q_table
    if q_table.save_raw_q_table_to_file(filename):
        print("Saved to file " + filename + " successfully!")
# Out:
# Episode number: 250. Total reward in episode: -1.6445629992550537. Episode executed with epsilon = 0.8132499999999929
# Average total reward in last 250 episodes: -1.6679717564337166
# -----
# Episode number: 500. Total reward in episode: -1.383958638586577. Episode executed with epsilon = 0.6257499999999858
# Average total reward in last 250 episodes: -1.6149566745938964
# -----
# Episode number: 750. Total reward in episode: -1.329033418688697. Episode executed with epsilon = 0.4382499999999833
# Average total reward in last 250 episodes: -1.5531273610561818
# -----
# Episode number: 1000. Total reward in episode: -1.3411686030739636. Episode executed with epsilon = 0.2507499999999901
# Average total reward in last 250 episodes: -1.5305129291730164
# -----
# Episode number: 1250. Total reward in episode: -1.2907529933145818. Episode executed with epsilon = 0.06324999999998993
# Average total reward in last 250 episodes: -1.4679768936431161
# -----
# Episode number: 1500. Total reward in episode: -1.7053898487481323. Episode executed with epsilon = -0.12425000000001021
# Average total reward in last 250 episodes: -1.410845281461364
# -----
# Episode number: 1750. Total reward in episode: -1.351863344536491. Episode executed with epsilon = -0.3117500000000081
# Average total reward in last 250 episodes: -1.4149993865810697
# -----
# Episode number: 2000. Total reward in episode: -1.3710535248049078. Episode executed with epsilon = -0.4992500000000013
# Average total reward in last 250 episodes: -1.4121633968737441
# -----
# Saved to file q_learning_tabular_problem_id_0.txt successfully!
# Episode number: 250. Total reward in episode: -1.902259453175646. Episode executed with epsilon = 0.8132499999999929
# Average total reward in last 250 episodes: -1.653404150232744
# -----
# Episode number: 500. Total reward in episode: -1.800078599596543. Episode executed with epsilon = 0.6257499999999858
# Average total reward in last 250 episodes: -1.6464761474357066
# -----
# Episode number: 750. Total reward in episode: -1.579728233178316. Episode executed with epsilon = 0.4382499999999833
# Average total reward in last 250 episodes: -1.579430128025847
# -----
# Episode number: 1000. Total reward in episode: -1.8337586479857315. Episode executed with epsilon = 0.2507499999999901
# Average total reward in last 250 episodes: -1.527955412668469
# -----
# Episode number: 1250. Total reward in episode: -1.33398992116991. Episode executed with epsilon = 0.06324999999998993
# Average total reward in last 250 episodes: -1.4554015223319525
# -----
# Episode number: 1500. Total reward in episode: -1.3496653101054186. Episode executed with epsilon = -0.12425000000001021
# Average total reward in last 250 episodes: -1.419592615314797
# -----
# Episode number: 1750. Total reward in episode: -1.3580772735768396. Episode executed with epsilon = -0.3117500000000081
# Average total reward in last 250 episodes: -1.4070311734166967
# -----
# Episode number: 2000. Total reward in episode: -1.2738334920552539. Episode executed with epsilon = -0.4992500000000013
# Average total reward in last 250 episodes: -1.41548107639155
# -----
# Saved to file q_learning_tabular_problem_id_1.txt successfully!
# Episode number: 250. Total reward in episode: -1.5895665085953092. Episode executed with epsilon = 0.8132499999999929
# Average total reward in last 250 episodes: -1.6599769395397794
# -----
# Episode number: 500. Total reward in episode: -1.5418074600194154. Episode executed with epsilon = 0.6257499999999858
# Average total reward in last 250 episodes: -1.6306243293631975
# -----
# Episode number: 750. Total reward in episode: -1.612238248269367. Episode executed with epsilon = 0.4382499999999833
# Average total reward in last 250 episodes: -1.5661645170449565
# -----
# Episode number: 1000. Total reward in episode: -1.440786801342417. Episode executed with epsilon = 0.2507499999999901
# Average total reward in last 250 episodes: -1.5533410730298667
# -----
# Episode number: 1250. Total reward in episode: -1.3965128586680735. Episode executed with epsilon = 0.06324999999998993
# Average total reward in last 250 episodes: -1.4619673099135024
# -----
# Episode number: 1500. Total reward in episode: -1.518829885080125. Episode executed with epsilon = -0.12425000000001021
# Average total reward in last 250 episodes: -1.4071953047746442
# -----
# Episode number: 1750. Total reward in episode: -1.4084931065167505. Episode executed with epsilon = -0.3117500000000081
# Average total reward in last 250 episodes: -1.4088229007840314
# -----
# Episode number: 2000. Total reward in episode: -1.4938352536336974. Episode executed with epsilon = -0.4992500000000013
# Average total reward in last 250 episodes: -1.4140674110462181
# -----
# Saved to file q_learning_tabular_problem_id_2.txt successfully!
# Episode number: 250. Total reward in episode: -1.6177866310176658. Episode executed with epsilon = 0.8132499999999929
# Average total reward in last 250 episodes: -1.6787979575556753
# -----
# Episode number: 500. Total reward in episode: -1.5474211099723634. Episode executed with epsilon = 0.6257499999999858
# Average total reward in last 250 episodes: -1.6233333987979508
# -----
# Episode number: 750. Total reward in episode: -1.9213218480784582. Episode executed with epsilon = 0.4382499999999833
# Average total reward in last 250 episodes: -1.5728790826404606
# -----
# Episode number: 1000. Total reward in episode: -1.537051585715025. Episode executed with epsilon = 0.2507499999999901
# Average total reward in last 250 episodes: -1.5325009413137247
# -----
# Episode number: 1250. Total reward in episode: -1.3235260026143276. Episode executed with epsilon = 0.06324999999998993
# Average total reward in last 250 episodes: -1.4536650074644977
# -----
# Episode number: 1500. Total reward in episode: -1.461959674733204. Episode executed with epsilon = -0.12425000000001021
# Average total reward in last 250 episodes: -1.414111602700988
# -----
# Episode number: 1750. Total reward in episode: -1.4624644021886448. Episode executed with epsilon = -0.3117500000000081
# Average total reward in last 250 episodes: -1.4032148859948301
# -----
# Episode number: 2000. Total reward in episode: -1.381934755213004. Episode executed with epsilon = -0.4992500000000013
# Average total reward in last 250 episodes: -1.3926041980589114
# -----
# Saved to file q_learning_tabular_problem_id_3.txt successfully!
# Episode number: 250. Total reward in episode: -1.8272057649842632. Episode executed with epsilon = 0.8132499999999929
# Average total reward in last 250 episodes: -1.6711272510379507
# -----
# Episode number: 500. Total reward in episode: -1.2487269723603052. Episode executed with epsilon = 0.6257499999999858
# Average total reward in last 250 episodes: -1.62516018714755
# -----
# Episode number: 750. Total reward in episode: -1.4473200254549654. Episode executed with epsilon = 0.4382499999999833
# Average total reward in last 250 episodes: -1.5690031131146698
# -----
# Episode number: 1000. Total reward in episode: -1.8842701855718633. Episode executed with epsilon = 0.2507499999999901
# Average total reward in last 250 episodes: -1.536733985010976
# -----
# Episode number: 1250. Total reward in episode: -1.466673830961449. Episode executed with epsilon = 0.06324999999998993
# Average total reward in last 250 episodes: -1.4483143848612516
# -----
# Episode number: 1500. Total reward in episode: -1.427003916170778. Episode executed with epsilon = -0.12425000000001021
# Average total reward in last 250 episodes: -1.4208526362893
# -----
# Episode number: 1750. Total reward in episode: -1.5371647139267302. Episode executed with epsilon = -0.3117500000000081
# Average total reward in last 250 episodes: -1.4012479424906934
# -----
# Episode number: 2000. Total reward in episode: -1.5787919244442026. Episode executed with epsilon = -0.4992500000000013
# Average total reward in last 250 episodes: -1.412053033672497
# -----
# Saved to file q_learning_tabular_problem_id_4.txt successfully!
# Episode number: 250. Total reward in episode: -2.029254853352814. Episode executed with epsilon = 0.8132499999999929
# Average total reward in last 250 episodes: -1.6733945212683161
# -----
# Episode number: 500. Total reward in episode: -1.4984059325241945. Episode executed with epsilon = 0.6257499999999858
# Average total reward in last 250 episodes: -1.6209879535048108
# -----
# Episode number: 750. Total reward in episode: -1.9120531735877142. Episode executed with epsilon = 0.4382499999999833
# Average total reward in last 250 episodes: -1.578280661855264
# -----
# Episode number: 1000. Total reward in episode: -1.6060094370669862. Episode executed with epsilon = 0.2507499999999901
# Average total reward in last 250 episodes: -1.5158475763932397
# -----
# Episode number: 1250. Total reward in episode: -1.4959992931946173. Episode executed with epsilon = 0.06324999999998993
# Average total reward in last 250 episodes: -1.4771726907702987
# -----
# Episode number: 1500. Total reward in episode: -1.3452512777607297. Episode executed with epsilon = -0.12425000000001021
# Average total reward in last 250 episodes: -1.4136798279562122
# -----
# Episode number: 1750. Total reward in episode: -1.4661412756224366. Episode executed with epsilon = -0.3117500000000081
# Average total reward in last 250 episodes: -1.4097340897514639
# -----
# Episode number: 2000. Total reward in episode: -1.3292598476269162. Episode executed with epsilon = -0.4992500000000013
# Average total reward in last 250 episodes: -1.4112305444371882
# -----
# Saved to file q_learning_tabular_problem_id_5.txt successfully!
# Episode number: 250. Total reward in episode: -1.2754781150923389. Episode executed with epsilon = 0.8132499999999929
# Average total reward in last 250 episodes: -1.6375467245957327
# -----
# Episode number: 500. Total reward in episode: -1.746134358838217. Episode executed with epsilon = 0.6257499999999858
# Average total reward in last 250 episodes: -1.6284055049267183
# -----
# Episode number: 750. Total reward in episode: -1.3134147962283402. Episode executed with epsilon = 0.4382499999999833
# Average total reward in last 250 episodes: -1.5779272832948654
# -----
# Episode number: 1000. Total reward in episode: -1.4951575007911404. Episode executed with epsilon = 0.2507499999999901
# Average total reward in last 250 episodes: -1.5116519803864035
# -----
# Episode number: 1250. Total reward in episode: -1.5565972225473856. Episode executed with epsilon = 0.06324999999998993
# Average total reward in last 250 episodes: -1.4706120113022105
# -----
# Episode number: 1500. Total reward in episode: -1.5822818982444924. Episode executed with epsilon = -0.12425000000001021
# Average total reward in last 250 episodes: -1.4102624752838355
# -----
# Episode number: 1750. Total reward in episode: -1.5324903460174588. Episode executed with epsilon = -0.3117500000000081
# Average total reward in last 250 episodes: -1.4161937934159696
# -----
# Episode number: 2000. Total reward in episode: -1.6147016283387157. Episode executed with epsilon = -0.4992500000000013
# Average total reward in last 250 episodes: -1.409047547281762
# -----
# Saved to file q_learning_tabular_problem_id_6.txt successfully!
# Episode number: 250. Total reward in episode: -2.0725921645180265. Episode executed with epsilon = 0.8132499999999929
# Average total reward in last 250 episodes: -1.6327697672863464
# -----
# Episode number: 500. Total reward in episode: -1.8485853498364087. Episode executed with epsilon = 0.6257499999999858
# Average total reward in last 250 episodes: -1.6410928927666995
# -----
# Episode number: 750. Total reward in episode: -1.6594024856403438. Episode executed with epsilon = 0.4382499999999833
# Average total reward in last 250 episodes: -1.5801208416343424
# -----
# Episode number: 1000. Total reward in episode: -1.7272995126649278. Episode executed with epsilon = 0.2507499999999901
# Average total reward in last 250 episodes: -1.5195640159038986
# -----
# Episode number: 1250. Total reward in episode: -1.3181448198733927. Episode executed with epsilon = 0.06324999999998993
# Average total reward in last 250 episodes: -1.466291470110757
# -----
# Episode number: 1500. Total reward in episode: -1.6865394983665822. Episode executed with epsilon = -0.12425000000001021
# Average total reward in last 250 episodes: -1.4026276357707073
# -----
# Episode number: 1750. Total reward in episode: -1.2913512068622965. Episode executed with epsilon = -0.3117500000000081
# Average total reward in last 250 episodes: -1.4052804572941804
# -----
# Episode number: 2000. Total reward in episode: -1.324213818374446. Episode executed with epsilon = -0.4992500000000013
# Average total reward in last 250 episodes: -1.4043733675986458
# -----
# Saved to file q_learning_tabular_problem_id_7.txt successfully!
# Episode number: 250. Total reward in episode: -1.5274809654457528. Episode executed with epsilon = 0.8132499999999929
# Average total reward in last 250 episodes: -1.6509441364920818
# -----
# Episode number: 500. Total reward in episode: -2.012382333055437. Episode executed with epsilon = 0.6257499999999858
# Average total reward in last 250 episodes: -1.6297557201208719
# -----
# Episode number: 750. Total reward in episode: -1.3462982842612. Episode executed with epsilon = 0.4382499999999833
# Average total reward in last 250 episodes: -1.572862477936549
# -----
# Episode number: 1000. Total reward in episode: -1.5350210546085226. Episode executed with epsilon = 0.2507499999999901
# Average total reward in last 250 episodes: -1.5221834326535717
# -----
# Episode number: 1250. Total reward in episode: -1.5766094384135443. Episode executed with epsilon = 0.06324999999998993
# Average total reward in last 250 episodes: -1.4726739047482984
# -----
# Episode number: 1500. Total reward in episode: -1.5030592022428833. Episode executed with epsilon = -0.12425000000001021
# Average total reward in last 250 episodes: -1.4051221042521798
# -----
# Episode number: 1750. Total reward in episode: -1.2780536461078795. Episode executed with epsilon = -0.3117500000000081
# Average total reward in last 250 episodes: -1.4146450705973777
# -----
# Episode number: 2000. Total reward in episode: -1.4040425660909956. Episode executed with epsilon = -0.4992500000000013
# Average total reward in last 250 episodes: -1.4337820392732101
# -----
# Saved to file q_learning_tabular_problem_id_8.txt successfully!
# Episode number: 250. Total reward in episode: -1.712120529651791. Episode executed with epsilon = 0.8132499999999929
# Average total reward in last 250 episodes: -1.658709783632336
# -----
# Episode number: 500. Total reward in episode: -1.429023935812488. Episode executed with epsilon = 0.6257499999999858
# Average total reward in last 250 episodes: -1.6232093891622599
# -----
# Episode number: 750. Total reward in episode: -1.5380873810713211. Episode executed with epsilon = 0.4382499999999833
# Average total reward in last 250 episodes: -1.5699410926102937
# -----
# Episode number: 1000. Total reward in episode: -1.5635134053528434. Episode executed with epsilon = 0.2507499999999901
# Average total reward in last 250 episodes: -1.5349582714748862
# -----
# Episode number: 1250. Total reward in episode: -1.450769911728376. Episode executed with epsilon = 0.06324999999998993
# Average total reward in last 250 episodes: -1.4604129953241831
# -----
# Episode number: 1500. Total reward in episode: -1.3874797134120924. Episode executed with epsilon = -0.12425000000001021
# Average total reward in last 250 episodes: -1.4119233101892328
# -----
# Episode number: 1750. Total reward in episode: -1.6498118093147407. Episode executed with epsilon = -0.3117500000000081
# Average total reward in last 250 episodes: -1.4082052566347572
# -----
# Episode number: 2000. Total reward in episode: -1.4698150386572373. Episode executed with epsilon = -0.4992500000000013
# Average total reward in last 250 episodes: -1.4044863500170663
# -----
# Saved to file q_learning_tabular_problem_id_9.txt successfully!
