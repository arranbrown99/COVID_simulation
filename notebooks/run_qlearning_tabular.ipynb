# %%
# use full window width
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import os
import numpy as np
os.chdir('..')
import virl
from plot_helper import plot
from q_learning_tabular.q_table import QTable
from q_learning_tabular.q_learning_agent import QLearningAgent
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Training and dumping q_tables for all problem ids

# %%
for i in range(0,10):
    filename = "trained_agents/q_learning_tabular_problem_id_" + str(i) + ".txt"    
    env = virl.Epidemic(stochastic=False, noisy=False)
    agent = QLearningAgent(env, print_out_every_x_episodes=25)
    agent.train()
    q_table = agent.q_table
    if q_table.save_raw_q_table_to_file(filename):
        print("Saved to file " + filename + " successfully!")
# Out:
# Episode number: 25. Total reward in episode: -1.7566819812999845. Episode executed with epsilon = 0.9819999999999993
# Average total reward in last 25 episodes: -1.606677390194488
# -----
# Episode number: 50. Total reward in episode: -1.8005287862878585. Episode executed with epsilon = 0.9632499999999986
# Average total reward in last 25 episodes: -1.6905714888905834
# -----
# Episode number: 75. Total reward in episode: -1.8324252374276695. Episode executed with epsilon = 0.9444999999999979
# Average total reward in last 25 episodes: -1.6823978033598654
# -----
# Episode number: 100. Total reward in episode: -1.4354793205967784. Episode executed with epsilon = 0.9257499999999972
# Average total reward in last 25 episodes: -1.6496359603432942
# -----
# Saved to file trained_agents/q_learning_tabular_problem_id_0BAD.txt successfully!
# Episode number: 25. Total reward in episode: -2.018939542988466. Episode executed with epsilon = 0.9819999999999993
# ...
